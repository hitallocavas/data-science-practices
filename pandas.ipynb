# %% [markdown]
# #Aula sobre Pandas

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# #Series

# %%
labels = ['a', 'b', 'c']
minha_lista = [10,20,30]
arr = np.array([10, 20, 30])
d = {'a': 10, 'b': 20, 'c': 30}

# %%
series = pd.Series(data=minha_lista, index=labels)

# %%
series['b']
# Out:
# 20

# %%
serie1 = pd.Series(data=[1,2,3,4], index = ['EUA', 'Alemanha', 'URSS', 'Japão'])

# %%
serie1
# Out:
# EUA         1
# Alemanha    2
# URSS        3
# Japão       4
# dtype: int64

# %%
serie2 = serie1 = pd.Series(data=[1,2,3,4], index = ['EUA', 'Alemanha', 'Itália', 'Japão'])

# %%
serie2
# Out:
# EUA         1
# Alemanha    2
# Itália      3
# Japão       4
# dtype: int64

# %%
serie1 + serie2
# Out:
# EUA         2
# Alemanha    4
# Itália      6
# Japão       8
# dtype: int64

# %% [markdown]
# #Criação e Fatiamento

# %%
df = pd.DataFrame(np.random.randn(5,4), index = "A B C D E".split(), columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df['W']
# Out:
# A    0.302665
# B   -0.134841
# C    0.807706
# D   -0.497104
# E   -0.116773
# Name: W, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  0.302665 -1.159119
# B -0.134841  0.184502
# C  0.807706  0.329646
# D -0.497104  0.484752
# E -0.116773  1.996652

# %%
df['TOTAL'] = df.W + df.X + df.Y + df.Z

# %%
df
# Out:
#           W         X         Y         Z     TOTAL
# A  0.302665  1.693723 -1.706086 -1.159119 -0.868817
# B -0.134841  0.390528  0.166905  0.184502  0.607094
# C  0.807706  0.072960  0.638787  0.329646  1.849099
# D -0.497104 -0.754070 -0.943406  0.484752 -1.709828
# E -0.116773  1.901755  0.238127  1.996652  4.019761

# %%
df.drop('TOTAL', axis=1)
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.drop('TOTAL', axis = 1, inplace=True)

# %%
df.loc['A']
# Out:
# W    0.302665
# X    1.693723
# Y   -1.706086
# Z   -1.159119
# Name: A, dtype: float64

# %%
df.loc['A','Z']
# Out:
# -1.1591194155484297

# %%
df.loc[['A', 'D'], ['W', 'Y']]
# Out:
#           W         Y
# A  0.302665 -1.706086
# D -0.497104 -0.943406

# %%
df.iloc[0:3, 2:]
# Out:
#           Y         Z
# A -1.706086 -1.159119
# B  0.166905  0.184502
# C  0.638787  0.329646

# %% [markdown]
# #Seleção Condicional

# %%
maior_que_zero = df > 0

# %%
df[maior_que_zero]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723       NaN       NaN
# B       NaN  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D       NaN       NaN       NaN  0.484752
# E       NaN  1.901755  0.238127  1.996652

# %%
df[df['W'] > 0]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# C  0.807706  0.072960  0.638787  0.329646

# %%
df[df['W'] > 0]['Y']
# Out:
# A   -1.706086
# C    0.638787
# Name: Y, dtype: float64

# %%
df[(df['W'] > 0) | (df['Y'] > 0)]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  0.302665  1.693723 -1.706086 -1.159119
# 1     B -0.134841  0.390528  0.166905  0.184502
# 2     C  0.807706  0.072960  0.638787  0.329646
# 3     D -0.497104 -0.754070 -0.943406  0.484752
# 4     E -0.116773  1.901755  0.238127  1.996652

# %%
col = 'RS RJ SP AM SC'.split()

# %%
df['Estado'] = col

# %%
df
# Out:
#           W         X         Y         Z Estado
# A  0.302665  1.693723 -1.706086 -1.159119     RS
# B -0.134841  0.390528  0.166905  0.184502     RJ
# C  0.807706  0.072960  0.638787  0.329646     SP
# D -0.497104 -0.754070 -0.943406  0.484752     AM
# E -0.116773  1.901755  0.238127  1.996652     SC

# %%
df.set_index('Estado')
# Out:
#                W         X         Y         Z
# Estado
# RS      0.302665  1.693723 -1.706086 -1.159119
# RJ     -0.134841  0.390528  0.166905  0.184502
# SP      0.807706  0.072960  0.638787  0.329646
# AM     -0.497104 -0.754070 -0.943406  0.484752
# SC     -0.116773  1.901755  0.238127  1.996652

# %% [markdown]
# #Índices Multi Níveis

# %%
#Níveis de Índice
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df = pd.DataFrame(np.random.randn(6,2), index = hier_index, columns=['A', 'B'])

# %%
df
# Out:
#              A         B
# G1 1 -0.993263  0.196800
#    2 -1.136645  0.000366
#    3  1.025984 -0.156598
# G2 1 -0.031579  0.649826
#    2  2.154846 -0.610259
#    3 -0.755325 -0.346419

# %%
df.loc['G1'].loc[1]
# Out:
# A   -0.993263
# B    0.196800
# Name: 1, dtype: float64

# %%
df.index.names = ['Grupo', 'Numero']

# %%
df
# Out:
#                      A         B
# Grupo Numero
# G1    1      -0.993263  0.196800
#       2      -1.136645  0.000366
#       3       1.025984 -0.156598
# G2    1      -0.031579  0.649826
#       2       2.154846 -0.610259
#       3      -0.755325 -0.346419

# %%
df.xs('G1')
# Out:
#                A         B
# Numero
# 1      -0.993263  0.196800
# 2      -1.136645  0.000366
# 3       1.025984 -0.156598

# %%
df.xs(1, level='Numero')
# Out:
#               A         B
# Grupo
# G1    -0.993263  0.196800
# G2    -0.031579  0.649826

# %% [markdown]
# #Tratamento de Dados Ausentes

# %%
d = {'A': [1,2,np.nan], 'B': [5, np.nan, np.nan], 'C': [6, 1, 2]}
d
# Out:
# {'A': [1, 2, nan], 'B': [5, nan, nan], 'C': [6, 1, 2]}

# %%
df = pd.DataFrame(d)
df
# Out:
#      A    B  C
# 0  1.0  5.0  6
# 1  2.0  NaN  1
# 2  NaN  NaN  2

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  6
# 1  2.0  NaN  1

# %%
df['A'].fillna(value = df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df.fillna(method='ffill')
# Out:
#      A    B  C
# 0  1.0  5.0  6
# 1  2.0  5.0  1
# 2  2.0  5.0  2

# %% [markdown]
# #Group By

# %%
import pandas as pd
# Cria um DataFrame
data = {'Empresa':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Nome':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Venda':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Empresa     Nome  Venda
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
group_by_empresa = df.groupby('Empresa')

# %%
group_by_empresa.sum()
# Out:
#          Venda
# Empresa
# FB         593
# GOOG       320
# MSFT       464

# %%
group_by_empresa.mean()
# Out:
#          Venda
# Empresa
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
group_by_empresa.describe()
# Out:
#         Venda
#         count   mean         std    min     25%    50%     75%    max
# Empresa
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %% [markdown]
# #Métodos de Junção de Dataframes

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
pd.concat([df1, df2, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
esquerda = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
direita = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
esquerda
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
direita
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(esquerda, direita, how='inner', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
esquerda = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

direita = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
esquerda
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
direita
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
esquerda.join(direita)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
esquerda_direita = esquerda.join(direita,how='outer')

# %%
esquerda_direita
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
esquerda_direita.fillna(method='pad')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K1  A1  B1  C0  D0
# K2  A2  B2  C2  D2
# K3  A2  B2  C3  D3

# %% [markdown]
# #Operações

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df[df['col1'] > 2]
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def vezes2(x):
  return x*2;

# %%
df.sum()
# Out:
# col1              10
# col2            2109
# col3    abcdefghixyz
# dtype: object

# %%
df['col2'].sum()
# Out:
# 2109

# %%
df['col1'].apply(vezes2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df[(df['col1']>2) & (df['col2'] == 444)]
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
df.col3.apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df.col2.apply(lambda x: (x*x)/(2*x))
# Out:
# 0    222.0
# 1    277.5
# 2    333.0
# 3    222.0
# Name: col2, dtype: float64

# %%
del df['col2']

# %%
df
# Out:
#    col1 col3
# 0     1  abc
# 1     2  def
# 2     3  ghi
# 3     4  xyz

# %%
df.columns
# Out:
# Index(['col1', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.sort_values(by='col2', inplace=True)

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 3  False  False  False
# 1  False  False  False
# 2  False  False  False

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.col1.fillna(value= df.col1.mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.0
# Name: col1, dtype: float64

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %% [markdown]
# #Entrada e Saída de Dados

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-25d17beb-d237-49cc-bf7a-ab01b3fe24c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25d17beb-d237-49cc-bf7a-ab01b3fe24c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exemplo.csv to exemplo.csv

# %%
import io

# %%
example_df = pd.read_csv(io.BytesIO(uploaded['exemplo.csv']))

# %%
example_df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-b99a45e3-9db0-4f48-9462-b2b32d7f52a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b99a45e3-9db0-4f48-9462-b2b32d7f52a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exemplo to exemplo

# %%
df = pd.read_csv(io.BytesIO(uploaded2['exemplo']), sep=',')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
